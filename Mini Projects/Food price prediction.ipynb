# %% [markdown]
# ## Food Price Prediction Using Restaurant Dataset Analysis

# %%
from sklearn.linear_model import LinearRegression
import pandas as pd
import statsmodels.api as st

# %%
df=pd.read_csv(r"C:\Users\admin\Desktop\Imarticus\restaurants.csv")
df
# Out:
#    Restaurant_ID  Food_Quality  Service_Quality  Price
# 0            ADS            22               20     43
# 1            BLG            20               19     32
# 2            CMK            21               18     34
# 3            KLS            20               17     41
# 4            IOS            24               21     54
# 5            UWO            22               21     52
# 6            USL            22               21     34
# 7            UKS            20               21     34
# 8            PLE            22               22     39
# 9            HEL            21               19     44
# 10           HQP            19               20     45
# 11           QUS            21               21     47
# 12           PLE            21               20     52
# 13           YWL            19               19     35
# 14           GQL            20               21     47
# 15           PEL            21               21     37
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Restaurant_ID    34 non-null     object
#  1   Food_Quality     34 non-null     int64
#  2   Service_Quality  34 non-null     int64
#  3   Price            34 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 1.2+ KB

# %%
df.shape
# Out:
# (34, 4)

# %%
df.isna().sum()
# Out:
# Restaurant_ID      0
# Food_Quality       0
# Service_Quality    0
# Price              0
# dtype: int64

# %%
df
# Out:
#    Restaurant_ID  Food_Quality  Service_Quality  Price
# 0            ADS            22               20     43
# 1            BLG            20               19     32
# 2            CMK            21               18     34
# 3            KLS            20               17     41
# 4            IOS            24               21     54
# 5            UWO            22               21     52
# 6            USL            22               21     34
# 7            UKS            20               21     34
# 8            PLE            22               22     39
# 9            HEL            21               19     44
# 10           HQP            19               20     45
# 11           QUS            21               21     47
# 12           PLE            21               20     52
# 13           YWL            19               19     35
# 14           GQL            20               21     47
# 15           PEL            21               21     37
# ...

# %%
x=df["Food_Quality"]
y=df["Price"]

# %%
import matplotlib.pyplot as plt
plt.hist(df.Price)
# Out:
# (array([6., 4., 2., 6., 2., 8., 4., 1., 0., 1.]),
#  array([32. , 35.3, 38.6, 41.9, 45.2, 48.5, 51.8, 55.1, 58.4, 61.7, 65. ]),
#  <BarContainer object of 10 artists>)

# %%
df.corr()
# Out:
#                  Food_Quality  Service_Quality     Price
# Food_Quality         1.000000         0.690637  0.566808
# Service_Quality      0.690637         1.000000  0.420823
# Price                0.566808         0.420823  1.000000

# %%
plt.bar(df.Food_Quality,df.Price,color="g")
plt.show()
plt.bar(df.Service_Quality,df.Price,color="r")
plt.show()

# %%
plt.scatter(df.Food_Quality,df.Price,color="g")
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x=st.add_constant(x)
model=st.OLS(y,x).fit()
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
summary=model.summary()
print(summary)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.321
# Model:                            OLS   Adj. R-squared:                  0.300
# Method:                 Least Squares   F-statistic:                     15.15
# Date:                Thu, 18 Aug 2022   Prob (F-statistic):           0.000474
# Time:                        16:04:24   Log-Likelihood:                -111.50
# No. Observations:                  34   AIC:                             227.0
# Df Residuals:                      32   BIC:                             230.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const          -23.9019     17.718     -1.349      0.187     -59.992      12.188
# ...

# %% [markdown]
# # Regression using Scikit learn

# %%
df.columns
# Out:
# Index(['Restaurant_ID', 'Food_Quality', 'Service_Quality', 'Price'], dtype='object')

# %%
df.drop(columns=["Restaurant_ID"],axis=1)
# Out:
#     Food_Quality  Service_Quality  Price
# 0             22               20     43
# 1             20               19     32
# 2             21               18     34
# 3             20               17     41
# 4             24               21     54
# 5             22               21     52
# 6             22               21     34
# 7             20               21     34
# 8             22               22     39
# 9             21               19     44
# 10            19               20     45
# 11            21               21     47
# 12            21               20     52
# 13            19               19     35
# 14            20               21     47
# 15            21               21     37
# 16            22               23     45
# 17            24               22     57
# 18            19               18     38
# 19            22               22     51
# 20            23               23     54
# 21            23               21     51
# ...

# %%
df.columns
# Out:
# Index(['Restaurant_ID', 'Food_Quality', 'Service_Quality', 'Price'], dtype='object')

# %%
x=df[['Food_Quality', 'Service_Quality']]
y=df["Price"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)
lr=LinearRegression()
ob=lr.fit(x_train,y_train)
ypred=ob.predict(x_test)
ypred1=ob.predict([[54,43]])
ypred1
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([146.38923873])

# %%
from sklearn.metrics import r2_score
r2_score(y_test,ypred)
# Out:
# 0.19898348610207672

# %%
ob.coef_
# Out:
# array([2.6763932, 0.5798374])

# %%
ob.intercept_
# Out:
# -23.069002217294887
